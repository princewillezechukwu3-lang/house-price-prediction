# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv(r"C:\Users\user\ml projects\house price project\House Price India.csv")

# %%
print(df.shape)
print(df.columns)
df.head()
# Out:
# (14619, 23)
# Index(['id', 'Date', 'number of bedrooms', 'number of bathrooms',
#        'living area', 'lot area', 'number of floors', 'waterfront present',
#        'number of views', 'condition of the house', 'grade of the house',
#        'Area of the house(excluding basement)', 'Area of the basement',
#        'Built Year', 'Renovation Year', 'Postal Code', 'Lattitude',
#        'Longitude', 'living_area_renov', 'lot_area_renov',
#        'Number of schools nearby', 'Distance from the airport', 'Price'],
#       dtype='object')
#            id   Date  number of bedrooms  number of bathrooms  living area  \
# 0  6762810635  42491                   4                 2.50         2920
# 1  6762810998  42491                   5                 2.75         2910
# 2  6762812605  42491                   4                 2.50         3310
# 3  6762812919  42491                   3                 2.00         2710
# ...

# %%
df.isnull().sum()
# Out:
# id                                       0
# Date                                     0
# number of bedrooms                       0
# number of bathrooms                      0
# living area                              0
# lot area                                 0
# number of floors                         0
# waterfront present                       0
# number of views                          0
# condition of the house                   0
# grade of the house                       0
# Area of the house(excluding basement)    0
# Area of the basement                     0
# Built Year                               0
# Renovation Year                          0
# Postal Code                              0
# Lattitude                                0
# Longitude                                0
# living_area_renov                        0
# lot_area_renov                           0
# Number of schools nearby                 0
# Distance from the airport                0
# ...

# %%
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14619 entries, 0 to 14618
# Data columns (total 23 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   id                                     14619 non-null  int64
#  1   Date                                   14619 non-null  int64
#  2   number of bedrooms                     14619 non-null  int64
#  3   number of bathrooms                    14619 non-null  float64
#  4   living area                            14619 non-null  int64
#  5   lot area                               14619 non-null  int64
#  6   number of floors                       14619 non-null  float64
#  7   waterfront present                     14619 non-null  int64
#  8   number of views                        14619 non-null  int64
#  9   condition of the house                 14619 non-null  int64
# ...

# %%
plt.figure(figsize=(12,8))
sns.heatmap(df.corr(), annot = True, cmap ='coolwarm')
plt.show()

sns.scatterplot(x='living area', y='Price', data=df)
plt.show()

sns.boxplot(x='number of bedrooms', y='Price', data=df)
plt.show()

# %%
df['Date'].value_counts()
# Out:
# Date
# 42543    142
# 42545    131
# 42546    131
# 42558    127
# 42559    121
#         ...
# 42584      1
# 42577      1
# 42611      1
# 42675      1
# 42703      1
# Name: count, Length: 241, dtype: int64

# %%
df = df.drop(columns=['id', 'Date'])

# %%
from sklearn.model_selection import train_test_split

x = df.drop('Price', axis=1)
y = df['Price']

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression

pipe = Pipeline([
    ('scaler', StandardScaler()),
    ('model', LinearRegression())
])

pipe.fit(x_train, y_train)
# Out:
# Pipeline(steps=[('scaler', StandardScaler()), ('model', LinearRegression())])

# %%
y_pred = pipe.predict(x_test)

# %%
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
import numpy as np

mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
mae = mean_absolute_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print(f"Mean Squared Error (MSE): {mse:.4f}")
print(f"Root Mean Squared Error (RMSE): {rmse:.4f}")
print(f"R2 Score: {r2:.4f}")
print(f"MAE: {mae:.4f}")
# Out:
# Mean Squared Error (MSE): 44109393059.2289
# Root Mean Squared Error (RMSE): 210022.3632
# R2 Score: 0.7020
# MAE: 125379.6646

# %%
features = x_train.columns
coefficients= pipe.named_steps['model'].coef_

feature_importance  = pd.DataFrame({
    'Feature': features,
    'Coefficient': coefficients
}).sort_values(by='Coefficient', ascending=False)

print(feature_importance)
# Out:
#                                   Feature    Coefficient
# 8                      grade of the house  116194.089433
# 2                             living area   81009.796193
# 9   Area of the house(excluding basement)   77008.349785
# 14                              Lattitude   76038.532972
# 5                      waterfront present   49664.214714
# 6                         number of views   37154.585390
# 1                     number of bathrooms   31351.284443
# 10                   Area of the basement   24332.753956
# 7                  condition of the house   21134.897273
# 16                      living_area_renov   13953.101517
# 12                        Renovation Year   11006.222650
# 13                            Postal Code    4039.538693
# 18               Number of schools nearby    2184.303453
# 4                        number of floors    1271.250318
# 3                                lot area     889.181060
# ...

# %%
from sklearn.linear_model import Ridge, Lasso
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import GridSearchCV

models = {
    "Linear Regression": LinearRegression(),
    "Ridge": Ridge(),
    "Lasso": Lasso(),
    "Random Forest": RandomForestRegressor(random_state=42)
}

results ={}
for name, model in models.items():
    pipe = Pipeline([
        ('scaler', StandardScaler()),
        ('model', model)
    ])
    pipe.fit(x_train, y_train)
    y_pred = pipe.predict(x_test)
    mse = mean_squared_error(y_test, y_pred)
    r2 = r2_score(y_test, y_pred)
    results[name] = {'MSE': mse, 'R2': r2}

pd.DataFrame(results).T
# Out:
# C:\Users\user\ml_env\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.432e+13, tolerance: 1.539e+11
#   model = cd_fast.enet_coordinate_descent(
#                             MSE        R2
# Linear Regression  4.410939e+10  0.701956
# Ridge              4.410975e+10  0.701953
# Lasso              4.410928e+10  0.701956
# Random Forest      1.769482e+10  0.880437

# %%
param_grid = {
    "n_estimators": [100, 300, 600,],
    "max_depth": [10, 20, None],
    "min_samples_split": [2, 5, 10]
}
rf = RandomForestRegressor(random_state=42)
search = GridSearchCV(rf, param_grid, cv=3, scoring="r2", n_jobs=-1)

search.fit(x_train, y_train)
print("Best parameters:" , search.best_params_)
print("BestR2:", search.best_score_)
# Out:
# Best parameters: {'max_depth': None, 'min_samples_split': 5, 'n_estimators': 300}
# BestR2: 0.8456317740271818

# %%
import joblib
best_model = search.best_estimator_

joblib.dump(best_model, "../models/house_price_model_compressed.pkl", compress=3)
print("Model saved successfully")
# Out:
# Model saved successfully

# %%
model = joblib.load("../models/house_price_model_compressed.pkl")
print("Model loaded successfully")
# Out:
# Model loaded successfully

# %%
sample_data = pd.DataFrame({
    "number of bedrooms": [3],
    "number of bathrooms": [2],
    "living area": [2900],
    "lot area": [10000],
    "number of floors": [1],
    "waterfront present": [0],
    "number of views": [2], 
    "condition of the house": [4],
    "grade of the house": [7],
    "Area of the house(excluding basement)": [1800], 
    "Area of the basement": [200],
    "Built Year": [2001],
    "Renovation Year": [0], 
    "Postal Code": [122009], 
    "Lattitude": [52.8878],
    "Longitude": [-114.590], 
    "living_area_renov": [2500], 
    "lot_area_renov": [6000],
    "Number of schools nearby": [2] , 
    "Distance from the airport": [70]
})

predicted_price = model.predict(sample_data)
print("Predicted price: ", predicted_price[0])
# Out:
# Predicted price:  760284.6286169388
